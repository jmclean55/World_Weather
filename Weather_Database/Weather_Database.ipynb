# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 622

# %%
# Import the requests library
import requests

# Import the API Key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# # Loop through all the cities in the list.
# for i in range(len(cities)):

#                # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)
        
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
 # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 11 | qaanaaq
# Processing Record 2 of Set 11 | nalut
# Processing Record 3 of Set 11 | vaini
# Processing Record 4 of Set 11 | butaritari
# Processing Record 5 of Set 11 | ushuaia
# Processing Record 6 of Set 11 | barcelos
# Processing Record 7 of Set 11 | arraial do cabo
# Processing Record 8 of Set 11 | chuy
# Processing Record 9 of Set 11 | mae hong son
# Processing Record 10 of Set 11 | port alfred
# Processing Record 11 of Set 11 | kapaa
# Processing Record 12 of Set 11 | northam
# Processing Record 13 of Set 11 | poole
# Processing Record 14 of Set 11 | rikitea
# Processing Record 15 of Set 11 | mogadishu
# Processing Record 16 of Set 11 | busselton
# Processing Record 17 of Set 11 | hobart
# Processing Record 18 of Set 11 | jamestown
# Processing Record 19 of Set 11 | kavaratti
# Processing Record 20 of Set 11 | new norfolk
# Processing Record 21 of Set 11 | ahipara
# Processing Record 22 of Set 11 | mount isa
# Processing Record 23 of Set 11 | byron bay
# Processing Record 24 of Set 11 | conde
# Processing Record 25 of Set 11 | kollam
# Processing Record 26 of Set 11 | hasaki
# Processing Record 27 of Set 11 | santarem
# Processing Record 28 of Set 11 | severomuysk
# Processing Record 29 of Set 11 | sao jose da coroa grande
# Processing Record 30 of Set 11 | cascais
# Processing Record 31 of Set 11 | thompson
# Processing Record 32 of Set 11 | yarada
# Processing Record 33 of Set 11 | mataura
# Processing Record 34 of Set 11 | tromso
# Processing Record 35 of Set 11 | hithadhoo
# Processing Record 36 of Set 11 | teguise
# Processing Record 37 of Set 11 | korla
# Processing Record 38 of Set 11 | geraldton
# Processing Record 39 of Set 11 | albany
# Processing Record 40 of Set 11 | barrow
# Processing Record 41 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 11 | vardo
# Processing Record 43 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 44 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | kaitangata
# Processing Record 46 of Set 11 | saint-philippe
# Processing Record 47 of Set 11 | lompoc
# Processing Record 48 of Set 11 | kodiak
# Processing Record 49 of Set 11 | myitkyina
# Processing Record 50 of Set 11 | banda aceh
# Processing Record 1 of Set 12 | goderich
# Processing Record 2 of Set 12 | tasiilaq
# Processing Record 3 of Set 12 | hirara
# Processing Record 4 of Set 12 | lebu
# Processing Record 5 of Set 12 | koundara
# Processing Record 6 of Set 12 | avarua
# Processing Record 7 of Set 12 | pangody
# Processing Record 8 of Set 12 | georgetown
# Processing Record 9 of Set 12 | ribeira grande
# Processing Record 10 of Set 12 | ilulissat
# Processing Record 11 of Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 12 | chokurdakh
# Processing Record 13 of Set 12 | fortuna
# Processing Record 14 of Set 12 | tilichiki
# Processing Record 15 of Set 12 | nikolskoye
# Processing Record 16 of Set 12 | krasnyy yar
# Processing Record 17 of Set 12 | victoria
# Processing Record 18 of Set 12 | hermanus
# Processing Record 19 of Set 12 | ahuimanu
# Processing Record 20 of Set 12 | porbandar
# Processing Record 21 of Set 12 | pevek
# Processing Record 22 of Set 12 | atuona
# Processing Record 23 of Set 12 | nhulunbuy
# Processing Record 24 of Set 12 | punta arenas
# Processing Record 25 of Set 12 | upernavik
# Processing Record 26 of Set 12 | dikson
# Processing Record 27 of Set 12 | codrington
# Processing Record 28 of Set 12 | east london
# Processing Record 29 of Set 12 | longyearbyen
# Processing Record 30 of Set 12 | jaguey grande
# Processing Record 31 of Set 12 | maumere
# Processing Record 32 of Set 12 | scarborough
# Processing Record 33 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 12 | port-gentil
# Processing Record 35 of Set 12 | stanislav
# Processing Record 36 of Set 12 | raga
# Processing Record 37 of Set 12 | springbok
# Processing Record 38 of Set 12 | we
# City not found. Skipping...
# Processing Record 39 of Set 12 | petropavlovka
# Processing Record 40 of Set 12 | berlevag
# Processing Record 41 of Set 12 | saurimo
# Processing Record 42 of Set 12 | puerto ayora
# Processing Record 43 of Set 12 | atar
# Processing Record 44 of Set 12 | coquimbo
# Processing Record 45 of Set 12 | barra patuca
# Processing Record 46 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 12 | rancho palos verdes
# Processing Record 48 of Set 12 | port elizabeth
# Processing Record 49 of Set 12 | port blair
# Processing Record 50 of Set 12 | bambous virieux
# Processing Record 1 of Set 13 | ponta do sol
# Processing Record 2 of Set 13 | abonnema
# Processing Record 3 of Set 13 | cape town
# Processing Record 4 of Set 13 | castro
# Processing Record 5 of Set 13 | saquarema
# Processing Record 6 of Set 13 | paita
# Processing Record 7 of Set 13 | santa rosa
# Processing Record 8 of Set 13 | kishi
# Processing Record 9 of Set 13 | bluff
# Processing Record 10 of Set 13 | egvekinot
# Processing Record 11 of Set 13 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 13 | mahebourg
# Processing Record 13 of Set 13 | nanortalik
# Processing Record 14 of Set 13 | haines junction
# Processing Record 15 of Set 13 | port lincoln
# Processing Record 16 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 13 | deputatskiy
# Processing Record 18 of Set 13 | ormara
# Processing Record 19 of Set 13 | skara
# Processing Record 20 of Set 13 | saskylakh
# Processing Record 21 of Set 13 | saint-pierre
# Processing Record 22 of Set 13 | lewiston
# Processing Record 23 of Set 13 | shenjiamen
# Processing Record 24 of Set 13 | birao
# Processing Record 25 of Set 13 | babushkin
# Processing Record 26 of Set 13 | cabo san lucas
# Processing Record 27 of Set 13 | half moon bay
# Processing Record 28 of Set 13 | naze
# Processing Record 29 of Set 13 | faanui
# Processing Record 30 of Set 13 | nome
# Processing Record 31 of Set 13 | staryy nadym
# Processing Record 32 of Set 13 | benguela
# Processing Record 33 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 13 | altay
# Processing Record 35 of Set 13 | bethel
# Processing Record 36 of Set 13 | same
# Processing Record 37 of Set 13 | wexford
# Processing Record 38 of Set 13 | alofi
# Processing Record 39 of Set 13 | port hardy
# Processing Record 40 of Set 13 | yellowknife
# Processing Record 41 of Set 13 | hirosaki
# Processing Record 42 of Set 13 | ishigaki
# Processing Record 43 of Set 13 | makakilo city
# Processing Record 44 of Set 13 | saint george
# Processing Record 45 of Set 13 | ancud
# Processing Record 46 of Set 13 | sainte-anne-des-monts
# Processing Record 47 of Set 13 | manturovo
# Processing Record 48 of Set 13 | losinyy
# Processing Record 49 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 13 | barranca
# Processing Record 1 of Set 14 | olinda
# Processing Record 2 of Set 14 | sortland
# Processing Record 3 of Set 14 | carnarvon
# Processing Record 4 of Set 14 | nantucket
# Processing Record 5 of Set 14 | qujing
# Processing Record 6 of Set 14 | hilo
# Processing Record 7 of Set 14 | virginia beach
# Processing Record 8 of Set 14 | high level
# Processing Record 9 of Set 14 | souillac
# Processing Record 10 of Set 14 | beringovskiy
# Processing Record 11 of Set 14 | shingu
# Processing Record 12 of Set 14 | severo-kurilsk
# Processing Record 13 of Set 14 | saint anthony
# Processing Record 14 of Set 14 | tonota
# Processing Record 15 of Set 14 | baykit
# Processing Record 16 of Set 14 | ostrovnoy
# Processing Record 17 of Set 14 | bengkulu
# Processing Record 18 of Set 14 | vestmannaeyjar
# Processing Record 19 of Set 14 | panguna
# Processing Record 20 of Set 14 | bredasdorp
# Processing Record 21 of Set 14 | shache
# Processing Record 22 of Set 14 | sao felix do xingu
# Processing Record 23 of Set 14 | lokken verk
# City not found. Skipping...
# Processing Record 24 of Set 14 | dudinka
# Processing Record 25 of Set 14 | changli
# Processing Record 26 of Set 14 | dano
# Processing Record 27 of Set 14 | tiksi
# Processing Record 28 of Set 14 | clyde river
# Processing Record 29 of Set 14 | tuktoyaktuk
# Processing Record 30 of Set 14 | corinto
# Processing Record 31 of Set 14 | san carlos
# Processing Record 32 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 14 | san vicente
# Processing Record 34 of Set 14 | torbay
# Processing Record 35 of Set 14 | point fortin
# Processing Record 36 of Set 14 | norman wells
# Processing Record 37 of Set 14 | yakshur-bodya
# City not found. Skipping...
# Processing Record 38 of Set 14 | oriximina
# Processing Record 39 of Set 14 | zhigansk
# Processing Record 40 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 14 | igurubi
# Processing Record 42 of Set 14 | lavrentiya
# Processing Record 43 of Set 14 | sao jose do egito
# Processing Record 44 of Set 14 | benjamin hill
# Processing Record 45 of Set 14 | havre-saint-pierre
# Processing Record 46 of Set 14 | ulaangom
# Processing Record 47 of Set 14 | anshun
# Processing Record 48 of Set 14 | komsomolskiy
# Processing Record 49 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 14 | ugoofaaru
# Processing Record 1 of Set 15 | wa
# City not found. Skipping...
# Processing Record 2 of Set 15 | bijela
# Processing Record 3 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 15 | san patricio
# Processing Record 5 of Set 15 | kaka
# Processing Record 6 of Set 15 | lazaro cardenas
# Processing Record 7 of Set 15 | raton
# Processing Record 8 of Set 15 | vila franca do campo
# Processing Record 9 of Set 15 | boddam
# Processing Record 10 of Set 15 | dorogino
# Processing Record 11 of Set 15 | hovd
# Processing Record 12 of Set 15 | ilhabela
# Processing Record 13 of Set 15 | osypenko
# Processing Record 14 of Set 15 | wajima
# Processing Record 15 of Set 15 | artigas
# Processing Record 16 of Set 15 | srednekolymsk
# Processing Record 17 of Set 15 | carbondale
# Processing Record 18 of Set 15 | panama city
# Processing Record 19 of Set 15 | torit
# Processing Record 20 of Set 15 | vanimo
# Processing Record 21 of Set 15 | okhotsk
# Processing Record 22 of Set 15 | taoudenni
# Processing Record 23 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 15 | bowen
# Processing Record 25 of Set 15 | opuwo
# Processing Record 26 of Set 15 | norfolk
# Processing Record 27 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 15 | liwale
# Processing Record 29 of Set 15 | yulara
# Processing Record 30 of Set 15 | karratha
# Processing Record 31 of Set 15 | tuatapere
# Processing Record 32 of Set 15 | griffith
# Processing Record 33 of Set 15 | iqaluit
# Processing Record 34 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 15 | mitsamiouli
# Processing Record 36 of Set 15 | pundaguitan
# Processing Record 37 of Set 15 | valparaiso
# Processing Record 38 of Set 15 | rotherham
# Processing Record 39 of Set 15 | harigue
# City not found. Skipping...
# Processing Record 40 of Set 15 | saint-francois
# Processing Record 41 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 15 | husavik
# Processing Record 43 of Set 15 | rudnogorsk
# Processing Record 44 of Set 15 | wanaka
# Processing Record 45 of Set 15 | milkovo
# Processing Record 46 of Set 15 | ilam
# Processing Record 47 of Set 15 | kawalu
# Processing Record 48 of Set 15 | afgoye
# City not found. Skipping...
# Processing Record 49 of Set 15 | ostuacan
# Processing Record 50 of Set 15 | terra santa
# Processing Record 1 of Set 16 | dingle
# Processing Record 2 of Set 16 | luderitz
# Processing Record 3 of Set 16 | lincoln
# Processing Record 4 of Set 16 | khatanga
# Processing Record 5 of Set 16 | waingapu
# Processing Record 6 of Set 16 | samana
# Processing Record 7 of Set 16 | thunder bay
# Processing Record 8 of Set 16 | sept-iles
# Processing Record 9 of Set 16 | north platte
# Processing Record 10 of Set 16 | hambantota
# Processing Record 11 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 16 | ixtapa
# Processing Record 14 of Set 16 | ploemeur
# Processing Record 15 of Set 16 | sao filipe
# Processing Record 16 of Set 16 | la palma
# Processing Record 17 of Set 16 | houma
# Processing Record 18 of Set 16 | galesong
# Processing Record 19 of Set 16 | kolyshley
# Processing Record 20 of Set 16 | cherskiy
# Processing Record 21 of Set 16 | sistranda
# Processing Record 22 of Set 16 | nileshwar
# Processing Record 23 of Set 16 | hue
# Processing Record 24 of Set 16 | borovichi
# Processing Record 25 of Set 16 | nouadhibou
# Processing Record 26 of Set 16 | el tigre
# Processing Record 27 of Set 16 | vao
# Processing Record 28 of Set 16 | hamilton
# Processing Record 29 of Set 16 | haverhill
# Processing Record 30 of Set 16 | broome
# Processing Record 31 of Set 16 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 16 | do gonbadan
# Processing Record 33 of Set 16 | narsaq
# Processing Record 34 of Set 16 | antalaha
# Processing Record 35 of Set 16 | ozark
# Processing Record 36 of Set 16 | tura
# Processing Record 37 of Set 16 | ibra
# Processing Record 38 of Set 16 | esperance
# Processing Record 39 of Set 16 | khuzdar
# Processing Record 40 of Set 16 | plettenberg bay
# Processing Record 41 of Set 16 | acajutla
# Processing Record 42 of Set 16 | chara
# Processing Record 43 of Set 16 | chipata
# Processing Record 44 of Set 16 | taunusstein
# Processing Record 45 of Set 16 | kangaatsiaq
# Processing Record 46 of Set 16 | coos bay
# Processing Record 47 of Set 16 | thaba-tseka
# Processing Record 48 of Set 16 | mehamn
# Processing Record 49 of Set 16 | luena
# Processing Record 50 of Set 16 | bud
# Processing Record 1 of Set 17 | sorland
# Processing Record 2 of Set 17 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 17 | isangel
# Processing Record 4 of Set 17 | awbari
# Processing Record 5 of Set 17 | stolin
# Processing Record 6 of Set 17 | sola
# Processing Record 7 of Set 17 | tiznit
# Processing Record 8 of Set 17 | saldanha
# Processing Record 9 of Set 17 | portland
# Processing Record 10 of Set 17 | yatou
# Processing Record 11 of Set 17 | salyan
# Processing Record 12 of Set 17 | oum hadjer
# Processing Record 13 of Set 17 | hongjiang
# Processing Record 14 of Set 17 | ola
# Processing Record 15 of Set 17 | avera
# Processing Record 16 of Set 17 | san policarpo
# Processing Record 17 of Set 17 | maues
# Processing Record 18 of Set 17 | dawson
# Processing Record 19 of Set 17 | chuzhou
# Processing Record 20 of Set 17 | mount gambier
# Processing Record 21 of Set 17 | mayo
# Processing Record 22 of Set 17 | lagoa
# Processing Record 23 of Set 17 | pecos
# Processing Record 24 of Set 17 | doha
# Processing Record 25 of Set 17 | miri
# Processing Record 26 of Set 17 | nelson
# Processing Record 27 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 17 | xining
# Processing Record 29 of Set 17 | grindavik
# Processing Record 30 of Set 17 | klaksvik
# Processing Record 31 of Set 17 | zachary
# Processing Record 32 of Set 17 | fort nelson
# Processing Record 33 of Set 17 | cidreira
# Processing Record 34 of Set 17 | cayenne
# Processing Record 35 of Set 17 | walvis bay
# Processing Record 36 of Set 17 | coromandel
# Processing Record 37 of Set 17 | moberly
# Processing Record 38 of Set 17 | krasnyy luch
# Processing Record 39 of Set 17 | palmer
# Processing Record 40 of Set 17 | bandar maharani
# City not found. Skipping...
# Processing Record 41 of Set 17 | bose
# Processing Record 42 of Set 17 | kahului
# Processing Record 43 of Set 17 | bara
# Processing Record 44 of Set 17 | mount pleasant
# Processing Record 45 of Set 17 | valle del guamuez
# Processing Record 46 of Set 17 | kruisfontein
# Processing Record 47 of Set 17 | misratah
# Processing Record 48 of Set 17 | tazovskiy
# Processing Record 49 of Set 17 | pareora
# Processing Record 50 of Set 17 | sarangani
# Processing Record 1 of Set 18 | kulob
# Processing Record 2 of Set 18 | acarau
# Processing Record 3 of Set 18 | calvinia
# Processing Record 4 of Set 18 | dzhankoy
# Processing Record 5 of Set 18 | touros
# Processing Record 6 of Set 18 | bogovarovo
# Processing Record 7 of Set 18 | hami
# Processing Record 8 of Set 18 | fairbanks
# Processing Record 9 of Set 18 | piacabucu
# Processing Record 10 of Set 18 | arlit
# Processing Record 11 of Set 18 | oktyabrskoye
# Processing Record 12 of Set 18 | ternate
# Processing Record 13 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 18 | jardim
# Processing Record 15 of Set 18 | sobolevo
# Processing Record 16 of Set 18 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 18 | sibolga
# Processing Record 18 of Set 18 | aurad
# Processing Record 19 of Set 18 | longkou
# Processing Record 20 of Set 18 | zhangjiakou
# Processing Record 21 of Set 18 | khilok
# Processing Record 22 of Set 18 | harstad
# Processing Record 23 of Set 18 | denpasar
# Processing Record 24 of Set 18 | malumfashi
# Processing Record 25 of Set 18 | meulaboh
# Processing Record 26 of Set 18 | necochea
# Processing Record 27 of Set 18 | prince rupert
# Processing Record 28 of Set 18 | gornoye loo
# Processing Record 29 of Set 18 | catuday
# Processing Record 30 of Set 18 | banting
# Processing Record 31 of Set 18 | kabanjahe
# Processing Record 32 of Set 18 | kirovsk
# Processing Record 33 of Set 18 | salima
# Processing Record 34 of Set 18 | puerto colombia
# Processing Record 35 of Set 18 | ambon
# Processing Record 36 of Set 18 | beaverlodge
# Processing Record 37 of Set 18 | yuzhno-kurilsk
# Processing Record 38 of Set 18 | mlowo
# Processing Record 39 of Set 18 | salalah
# Processing Record 40 of Set 18 | los llanos de aridane
# Processing Record 41 of Set 18 | dubbo
# Processing Record 42 of Set 18 | salvador
# Processing Record 43 of Set 18 | la ronge
# Processing Record 44 of Set 18 | estevan
# Processing Record 45 of Set 18 | altamira
# Processing Record 46 of Set 18 | constitucion
# Processing Record 47 of Set 18 | selizharovo
# Processing Record 48 of Set 18 | ugarcin
# City not found. Skipping...
# Processing Record 49 of Set 18 | san quintin
# Processing Record 50 of Set 18 | mukhen
# Processing Record 1 of Set 19 | kallaste
# Processing Record 2 of Set 19 | erzin
# Processing Record 3 of Set 19 | kailua
# Processing Record 4 of Set 19 | berlin
# Processing Record 5 of Set 19 | waddan
# Processing Record 6 of Set 19 | podbelsk
# City not found. Skipping...
# Processing Record 7 of Set 19 | rafaela
# Processing Record 8 of Set 19 | blythe
# Processing Record 9 of Set 19 | jequitinhonha
# Processing Record 10 of Set 19 | salcia
# Processing Record 11 of Set 19 | cheyur
# City not found. Skipping...
# Processing Record 12 of Set 19 | dawei
# Processing Record 13 of Set 19 | kontagora
# Processing Record 14 of Set 19 | leh
# Processing Record 15 of Set 19 | zlitan
# Processing Record 16 of Set 19 | cooma
# Processing Record 17 of Set 19 | cassilandia
# Processing Record 18 of Set 19 | provideniya
# Processing Record 19 of Set 19 | sambava
# Processing Record 20 of Set 19 | gouloure
# Processing Record 21 of Set 19 | aktau
# Processing Record 22 of Set 19 | pacific grove
# Processing Record 23 of Set 19 | yithion
# City not found. Skipping...
# Processing Record 24 of Set 19 | marfino
# Processing Record 25 of Set 19 | leningradskiy
# Processing Record 26 of Set 19 | brasileia
# Processing Record 27 of Set 19 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 19 | kudahuvadhoo
# Processing Record 29 of Set 19 | acapulco
# Processing Record 30 of Set 19 | rocha
# Processing Record 31 of Set 19 | russell
# Processing Record 32 of Set 19 | limoeiro do ajuru
# Processing Record 33 of Set 19 | katsuura
# Processing Record 34 of Set 19 | san francisco
# Processing Record 35 of Set 19 | oistins
# Processing Record 36 of Set 19 | kavieng
# Processing Record 37 of Set 19 | kosonsoy
# Processing Record 38 of Set 19 | marawi
# Processing Record 39 of Set 19 | adelaide
# Processing Record 40 of Set 19 | roald
# Processing Record 41 of Set 19 | tokonou
# Processing Record 42 of Set 19 | kytlym
# City not found. Skipping...
# Processing Record 43 of Set 19 | baghdad
# Processing Record 44 of Set 19 | mattru
# Processing Record 45 of Set 19 | santona
# Processing Record 46 of Set 19 | talnakh
# Processing Record 47 of Set 19 | imbituba
# Processing Record 48 of Set 19 | viedma
# Processing Record 49 of Set 19 | the valley
# Processing Record 50 of Set 19 | pozo colorado
# Processing Record 1 of Set 20 | north bend
# Processing Record 2 of Set 20 | tombouctou
# Processing Record 3 of Set 20 | portel
# Processing Record 4 of Set 20 | sur
# Processing Record 5 of Set 20 | mabaruma
# Processing Record 6 of Set 20 | zhuhai
# Processing Record 7 of Set 20 | arman
# Processing Record 8 of Set 20 | esna
# Processing Record 9 of Set 20 | nola
# Processing Record 10 of Set 20 | zabol
# Processing Record 11 of Set 20 | progreso
# Processing Record 12 of Set 20 | guanare
# Processing Record 13 of Set 20 | catamarca
# Processing Record 14 of Set 20 | baruun-urt
# Processing Record 15 of Set 20 | porto torres
# Processing Record 16 of Set 20 | alagoinhas
# Processing Record 17 of Set 20 | benin
# Processing Record 18 of Set 20 | westport
# Processing Record 19 of Set 20 | wiesmoor
# Processing Record 20 of Set 20 | kimbe
# Processing Record 21 of Set 20 | xucheng
# Processing Record 22 of Set 20 | lasa
# Processing Record 23 of Set 20 | udachnyy
# Processing Record 24 of Set 20 | vryburg
# Processing Record 25 of Set 20 | amahai
# Processing Record 26 of Set 20 | sao gabriel da cachoeira
# Processing Record 27 of Set 20 | san ramon
# Processing Record 28 of Set 20 | batsfjord
# Processing Record 29 of Set 20 | logstor
# Processing Record 30 of Set 20 | raahe
# Processing Record 31 of Set 20 | kuusamo
# Processing Record 32 of Set 20 | guerrero negro
# Processing Record 33 of Set 20 | pendleton
# Processing Record 34 of Set 20 | chabahar
# Processing Record 35 of Set 20 | hirado
# Processing Record 36 of Set 20 | airai
# Processing Record 37 of Set 20 | hofn
# Processing Record 38 of Set 20 | krasnoselkup
# Processing Record 39 of Set 20 | mchinji
# Processing Record 40 of Set 20 | izberbash
# Processing Record 41 of Set 20 | san luis
# Processing Record 42 of Set 20 | grand gaube
# Processing Record 43 of Set 20 | novikovo
# Processing Record 44 of Set 20 | batak
# Processing Record 45 of Set 20 | calais
# Processing Record 46 of Set 20 | jurm
# Processing Record 47 of Set 20 | rio maior
# Processing Record 48 of Set 20 | san cristobal
# Processing Record 49 of Set 20 | zakupne
# Processing Record 50 of Set 20 | magalia
# Processing Record 1 of Set 21 | manado
# Processing Record 2 of Set 21 | kieta
# Processing Record 3 of Set 21 | gigmoto
# Processing Record 4 of Set 21 | itarema
# Processing Record 5 of Set 21 | toyooka
# Processing Record 6 of Set 21 | bafq
# Processing Record 7 of Set 21 | cap-aux-meules
# Processing Record 8 of Set 21 | luis correia
# Processing Record 9 of Set 21 | troitsko-pechorsk
# Processing Record 10 of Set 21 | sapao
# City not found. Skipping...
# Processing Record 11 of Set 21 | sonoita
# Processing Record 12 of Set 21 | muros
# Processing Record 13 of Set 21 | rio gallegos
# Processing Record 14 of Set 21 | vila velha
# Processing Record 15 of Set 21 | zalantun
# Processing Record 16 of Set 21 | port shepstone
# Processing Record 17 of Set 21 | belle fourche
# Processing Record 18 of Set 21 | beloha
# Processing Record 19 of Set 21 | ampanihy
# Processing Record 20 of Set 21 | kovdor
# Processing Record 21 of Set 21 | seoul
# Processing Record 22 of Set 21 | lixourion
# Processing Record 23 of Set 21 | boone
# Processing Record 24 of Set 21 | rosetta
# Processing Record 25 of Set 21 | zaltan
# Processing Record 26 of Set 21 | sechura
# Processing Record 27 of Set 21 | coronado
# Processing Record 28 of Set 21 | camopi
# Processing Record 29 of Set 21 | wasilla
# Processing Record 30 of Set 21 | al
# City not found. Skipping...
# Processing Record 31 of Set 21 | tingo maria
# Processing Record 32 of Set 21 | faya
# Processing Record 33 of Set 21 | panorama
# Processing Record 34 of Set 21 | honningsvag
# Processing Record 35 of Set 21 | belaya gora
# Processing Record 36 of Set 21 | sao miguel do araguaia
# Processing Record 37 of Set 21 | kizema
# Processing Record 38 of Set 21 | buala
# Processing Record 39 of Set 21 | yerbogachen
# Processing Record 40 of Set 21 | skjervoy
# Processing Record 41 of Set 21 | hope mills
# Processing Record 42 of Set 21 | marsh harbour
# Processing Record 43 of Set 21 | forio
# Processing Record 44 of Set 21 | puerto narino
# Processing Record 45 of Set 21 | lata
# Processing Record 46 of Set 21 | jarwal
# Processing Record 47 of Set 21 | omboue
# Processing Record 48 of Set 21 | chivay
# Processing Record 49 of Set 21 | lorengau
# Processing Record 50 of Set 21 | tahta
# Processing Record 1 of Set 22 | flinders
# Processing Record 2 of Set 22 | bilma
# Processing Record 3 of Set 22 | christchurch
# Processing Record 4 of Set 22 | gawler
# Processing Record 5 of Set 22 | henties bay
# Processing Record 6 of Set 22 | poum
# Processing Record 7 of Set 22 | requena
# Processing Record 8 of Set 22 | tarime
# Processing Record 9 of Set 22 | watrous
# Processing Record 10 of Set 22 | abu dhabi
# Processing Record 11 of Set 22 | coffs harbour
# Processing Record 12 of Set 22 | abomey-calavi
# Processing Record 13 of Set 22 | malko tarnovo
# Processing Record 14 of Set 22 | coihaique
# Processing Record 15 of Set 22 | andarab
# City not found. Skipping...
# Processing Record 16 of Set 22 | yaya
# Processing Record 17 of Set 22 | marquette
# Processing Record 18 of Set 22 | rondonopolis
# Processing Record 19 of Set 22 | perove
# Processing Record 20 of Set 22 | maniitsoq
# Processing Record 21 of Set 22 | chokwe
# Processing Record 22 of Set 22 | camacha
# Processing Record 23 of Set 22 | rawicz
# Processing Record 24 of Set 22 | itoman
# Processing Record 25 of Set 22 | bitung
# Processing Record 26 of Set 22 | bathsheba
# Processing Record 27 of Set 22 | never
# Processing Record 28 of Set 22 | abong mbang
# Processing Record 29 of Set 22 | copiapo
# Processing Record 30 of Set 22 | tuggurt
# City not found. Skipping...
# Processing Record 31 of Set 22 | adrar
# Processing Record 32 of Set 22 | emerald
# Processing Record 33 of Set 22 | pahrump
# Processing Record 34 of Set 22 | calabar
# Processing Record 35 of Set 22 | tarko-sale
# Processing Record 36 of Set 22 | saint-joseph
# Processing Record 37 of Set 22 | san antonio
# Processing Record 38 of Set 22 | nizhniy kuranakh
# Processing Record 39 of Set 22 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 22 | maningrida
# Processing Record 41 of Set 22 | irtyshskiy
# Processing Record 42 of Set 22 | mar del plata
# Processing Record 43 of Set 22 | rio grande
# Processing Record 44 of Set 22 | vadso
# Processing Record 45 of Set 22 | wahiawa
# Processing Record 46 of Set 22 | dunedin
# Processing Record 47 of Set 22 | pemba
# Processing Record 48 of Set 22 | oxchuc
# Processing Record 49 of Set 22 | manakara
# Processing Record 50 of Set 22 | mackay
# Processing Record 1 of Set 23 | beypur
# City not found. Skipping...
# Processing Record 2 of Set 23 | sosnovo-ozerskoye
# Processing Record 3 of Set 23 | amuntai
# Processing Record 4 of Set 23 | diamantino
# Processing Record 5 of Set 23 | jining
# Processing Record 6 of Set 23 | minsk
# Processing Record 7 of Set 23 | koungheul
# Processing Record 8 of Set 23 | yar-sale
# Processing Record 9 of Set 23 | yangambi
# Processing Record 10 of Set 23 | vicksburg
# Processing Record 11 of Set 23 | la serena
# Processing Record 12 of Set 23 | moron
# Processing Record 13 of Set 23 | aakirkeby
# City not found. Skipping...
# Processing Record 14 of Set 23 | teknaf
# Processing Record 15 of Set 23 | santo domingo
# Processing Record 16 of Set 23 | cruzeiro do sul
# Processing Record 17 of Set 23 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 23 | jalu
# Processing Record 19 of Set 23 | lagos
# Processing Record 20 of Set 23 | namatanai
# Processing Record 21 of Set 23 | puerto baquerizo moreno
# Processing Record 22 of Set 23 | ossora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Qaanaaq  77.4840  -69.3632     17.01        72          22
# 1            Nalut  30.3333   10.8500     87.04        11          11
# 2            Vaini -21.2000 -175.2000     73.56        78          40
# 3       Butaritari   3.0707  172.7902     80.85        83          66
# 4          Ushuaia -54.8000  -68.3000     40.66        75          75
# 5         Barcelos  41.5388   -8.6151     65.84        71          50
# 6  Arraial Do Cabo -22.9661  -42.0278     84.16        69          20
# 7             Chuy -33.6971  -53.4616     71.83        81         100
# 8     Mae Hong Son  19.3003   97.9685     81.05        53          20
# 9      Port Alfred -33.5906   26.8910     61.18        85          11
#
#    Wind Speed Country                 Date
# 0        4.83      GL  2022-04-26 16:37:16
# 1       20.36      LY  2022-04-26 16:37:16
# 2       10.36      TO  2022-04-26 16:37:16
# 3       18.14      KI  2022-04-26 16:37:17
# 4        3.44      AR  2022-04-26 16:37:17
# 5        7.72      PT  2022-04-26 16:34:18
# 6       14.97      BR  2022-04-26 16:37:17
# 7       11.25      UY  2022-04-26 16:37:17
# 8        1.36      TH  2022-04-26 16:37:18
# 9        4.00      ZA  2022-04-26 16:37:18

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
len(city_data_df)
# Out:
# 577

# %%
output_data= "WeatherPy_Database.csv"

# %%
city_data_df.to_csv(output_data,index_label="City_ID")
